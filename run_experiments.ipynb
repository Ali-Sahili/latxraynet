# %% [markdown]
# # **Demo with Colab**

# %% [markdown]
# ### **Download dataset**

# %%
## DOWNLOAD Dataset and PUT it into data/2026 folder (check README.md)

# %% [markdown]
# ### **Download the code package and install it**

# %%
# clone package
# !git clone https://github.com/Ali-Sahili/latxraynet

# %%
# install dependencies
cd /content/
cd latxraynet/
# !pip install e .

# %%
# verify installation
# !python -c "import latxraynet; print(latxraynet.__file__)"

# %% [markdown]
# ### **Run Experiments**

# %%
# run first experiment
# !python run_experiments/1_first_approach_best.py
